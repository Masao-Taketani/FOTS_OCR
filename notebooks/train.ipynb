# %% [markdown]
# <table align="center"><td>
#   <a target="_blank"  href="https://colab.research.google.com/github/Masao-Taketani/FOTS_OCR/blob/master/notebooks/train.ipynbb">
#     <img width=32px src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
# </td></table>

# %%
import os

if "FOTS_OCR" not in os.getcwd():
    # !git clone https://github.com/Masao-Taketani/FOTS_OCR.git
    os.chdir('FOTS_OCR')
# Out:
# Cloning into 'FOTS_OCR'...
